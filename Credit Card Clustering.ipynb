# %% [markdown]
# # Credit Card Clustering

# %% [markdown]
# ### In this lesson, we will explain credit card holders' purchasing habits, limits, etc. We will make clustering

# %% [markdown]
# <a href='https://www.kaggle.com/datasets/arjunbhasin2013/ccdata/data' target=_blank>You can find the data file here</a>

# %% [markdown]
# <img src=https://storage.googleapis.com/kaggle-datasets-images/310/684/3503c6c827ca269cc00ffa66f2a9c207/dataset-card.jpg width='400'>

# %%
import pandas as pd
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('CC GENERAL.csv')

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['CUST_ID'].value_counts()
# Out:
# CUST_ID
# C10001    1
# C16135    1
# C16129    1
# C16130    1
# C16131    1
#          ..
# C13065    1
# C13064    1
# C13063    1
# C13062    1
# C19190    1
# Name: count, Length: 8950, dtype: int64

# %%
df = df.drop('CUST_ID', axis=1)

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())

# %%
#pip install yellowbrick

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
wcss=[]
ss=[]
for i in range(2,14):
    model=KMeans(i)
    model=model.fit(df)
    tahmin=model.predict(df)
    ss1=silhouette_score(df,tahmin)
    ss.append(ss1)
    print(ss1)
    wcss.append(model.inertia_)
# Out:
# 0.5145025569999819
# 0.46510840738141906
# 0.3986241317244963
# 0.37165766239489917
# 0.3982528137126423
# 0.37345737750586566
# 0.38168583630874825
# 0.38926018722064465
# 0.36148099477817647
# 0.3003756957482329
# 0.33607841686458634
# 0.28730459731949654

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(2,14),wcss)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans(random_state=42)

visualizer = KElbowVisualizer(model, k=(2,10), metric='distortion', timings=False)

visualizer.fit(df)  
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
silhouette_score(df,tahmin)
# Out:
# 0.28730459731949654

# %%
model=KMeans(6)

# %%
model.fit(df)
# Out:
# KMeans(n_clusters=6)

# %%
model=model.fit(df)

# %%
tahmin=model.predict(df)

# %%
tahmin
# Out:
# array([3, 2, 1, ..., 3, 3, 3], dtype=int32)

# %%
df['cluster']=tahmin

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df['cluster'].value_counts()
# Out:
# cluster
# 3    5562
# 1    2275
# 2     649
# 5     394
# 4      38
# 0      32
# Name: count, dtype: int64

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data=linkage(df, method='ward', metric='euclidean')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25,6))

# %%
dendrogram(data);

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))  
sns.countplot(x=df['cluster'])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.BALANCE,df.PURCHASES, c=tahmin, cmap='viridis')
plt.colorbar()
plt.xlabel('Balance')
plt.ylabel('number of purchases')
# Out:
# Text(0, 0.5, 'number of purchases')

# %% [markdown]
# ### In this data, according to KMeans and Yellowbrick, the most accurate way was to divide the Customers into 6 classes. With these classes, the bank can provide easier service to its customers, for example, it can offer personalized loans
